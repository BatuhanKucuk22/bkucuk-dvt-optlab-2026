# %%
# ==============================================================================
# 🛡️ HÜCRE 1: ÇEKİRDEK ORTAM, ZIRHLAMA VE BAĞIMLILIKLAR
# ==============================================================================
import os, sys, gc, subprocess, glob
from google.colab import drive

if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

print("📦 1. Kütüphaneler kuruluyor...")
subprocess.run([sys.executable, "-m", "pip", "install", "-q",
                "opencv-python", "matplotlib", "scikit-image", "einops", "kornia",
                "timm", "yacs", "joblib", "natsort", "h5py", "tqdm", "ptflops",
                "seaborn", "addict", "future", "lmdb", "numpy", "pyyaml", "requests",
                "scipy", "yapf", "lpips", "cython", "cython_bbox", "pandas",
                "xmltodict", "loguru", "gdown", "lapx", "motmetrics", "filterpy",
                "thop", "faiss-cpu", "tabulate"])

print("📥 2. Repolar klonlanıyor (DeepRFT, LightStab, HybridSORT)...")
for repo, url in [("DeepRFT", "https://github.com/INVOKERer/DeepRFT.git -b AAAI2023"),
                  ("LightStab", "https://github.com/liutao23/LightStab.git"),
                  ("HybridSORT", "https://github.com/ymzis69/HybridSORT.git")]:
    if not os.path.exists(f'/content/{repo}'):
        os.system(f"git clone {url} /content/{repo}")

print("🛠️ 3. Sistem yamaları (NumPy 2.x & Headless Matplotlib) uygulanıyor...")
# LightStab Headless Yama
ls_file = "/content/LightStab/model/LightMotionEsitimation.py"
if os.path.exists(ls_file):
    with open(ls_file, "r") as f: c = f.read()
    with open(ls_file, "w") as f: f.write(c.replace("matplotlib.use('TkAgg')", "matplotlib.use('Agg')"))

# HybridSORT NumPy 2.x Yaması
for py_file in glob.glob("/content/HybridSORT/**/*.py", recursive=True):
    try:
        with open(py_file, 'r', encoding='utf-8') as f: code = f.read()
        for old, new in [("np.float(", "float("), ("np.int(", "int("), ("np.bool(", "bool("),
                         ("astype(float32)", "astype(np.float32)"), ("dtype=float32", "dtype=np.float32"),
                         ("astype(int32)", "astype(np.int32)")]:
            code = code.replace(old, new)
        with open(py_file, 'w', encoding='utf-8') as f: f.write(code)
    except: pass

os.chdir("/content/HybridSORT")
if not os.path.exists("yolox.egg-info"):
    os.system("pip install -e . --no-build-isolation --no-deps -q")
os.chdir("/content")

print("✅ Hücre 1 Tamamlandı: Ortam %100 Hazır ve Zırhlı.")
# Out:
# Mounted at /content/drive
# 📦 1. Kütüphaneler kuruluyor...
# 📥 2. Repolar klonlanıyor (DeepRFT, LightStab, HybridSORT)...
# 🛠️ 3. Sistem yamaları (NumPy 2.x & Headless Matplotlib) uygulanıyor...
# ✅ Hücre 1 Tamamlandı: Ortam %100 Hazır ve Zırhlı.

# %%
# ==============================================================================
# 📂 HÜCRE 2: VERİSETİ BAĞLANTISI (MOT17-04) VE İLKLEME
# ==============================================================================
import os
import glob
import cv2
import torch
import shutil

# 1. Veriseti Yolları (Drive'a yeni yüklediğin MOT17-04 dizini)
dataset_base = "/content/drive/MyDrive/Spikedge_Staj/Tracking/MOT17_Dataset/train/MOT17-04-FRCNN"
img_dir = os.path.join(dataset_base, "img1")
gt_path = os.path.join(dataset_base, "gt/gt.txt")

image_files = sorted(glob.glob(os.path.join(img_dir, "*.jpg")))

print("="*50)
print(f"📁 Seçilen Senaryo: MOT17-04-FRCNN")
print(f"🎞️ Toplam Kare Sayısı: {len(image_files)}")
print(f"📊 Ground Truth Konumu: {gt_path}")
print("="*50)

if not image_files:
    raise FileNotFoundError("❌ Görüntüler bulunamadı! Drive yolunu kontrol edin.")
if not os.path.exists(gt_path):
    raise FileNotFoundError("❌ gt.txt bulunamadı! Verisetinin eksiksiz yüklendiğinden emin olun.")

# 2. YOLOX Ağırlık Yükleme ve Zırhlı Taşıma
drive_yolox = "/content/drive/MyDrive/Spikedge_Staj/Tracking/pretrained/ocsort_x_mot17.pth.tar"
local_yolox = "/content/HybridSORT/pretrained/ocsort_x_mot17.pth.tar"

os.makedirs(os.path.dirname(local_yolox), exist_ok=True)
if os.path.exists(drive_yolox) and not os.path.exists(local_yolox):
    shutil.copy(drive_yolox, local_yolox)
    print("📥 YOLOX modeli Drive'dan çekildi.")
elif not os.path.exists(local_yolox):
    raise FileNotFoundError(f"❌ {drive_yolox} konumunda model bulunamadı!")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Hücre 2 Tamamlandı: Veriseti dizinlendi. Çalışma birimi: {device.type.upper()}")
# Out:
# ==================================================
# 📁 Seçilen Senaryo: MOT17-04-FRCNN
# 🎞️ Toplam Kare Sayısı: 1050
# 📊 Ground Truth Konumu: /content/drive/MyDrive/Spikedge_Staj/Tracking/MOT17_Dataset/train/MOT17-04-FRCNN/gt/gt.txt
# ==================================================
# 📥 YOLOX modeli Drive'dan çekildi.
# ✅ Hücre 2 Tamamlandı: Veriseti dizinlendi. Çalışma birimi: CUDA

# %%
# ==============================================================================
# 🛡️ YENİ HÜCRE 2.5: DEEPRFT ORİJİNAL COMMIT ENTEGRASYONU (DEC 5, 2021)
# ==============================================================================
import os
import sys
import subprocess
import importlib.util
import shutil

print("⚡ [Sistem] DeepRFT orijinal commit (Dec 5, 2021) yapılandırılıyor...", flush=True)

subprocess.run([sys.executable, "-m", "pip", "install", "einops", "timm", "kornia", "ptflops", "natsort", "yacs", "joblib", "addict", "future", "yapf", "lpips", "-q"])

deeprft_dir = "/content/DeepRFT"
if os.path.exists(deeprft_dir):
    shutil.rmtree(deeprft_dir)

print(" 📥 DeepRFT reposu klonlanıyor...", flush=True)
subprocess.run(["git", "clone", "https://github.com/INVOKERer/DeepRFT.git", deeprft_dir])

# 🛠️ Ekran görüntüsündeki orijinal commit'e git!
os.chdir(deeprft_dir)
# Ekran görüntüsünün commit hash'i veya en yakın kararlı sürüm
subprocess.run(["git", "checkout", "a88bf49"])
os.chdir("/content")

if deeprft_dir not in sys.path:
    sys.path.insert(0, deeprft_dir)

try:
    file_path = os.path.join(deeprft_dir, "DeepRFT_MIMO.py")
    if not os.path.exists(file_path):
        raise Exception("DeepRFT_MIMO.py dosyası commit içinde bulunamadı!")

    print(" 🔍 DeepRFT_MIMO.py modülü fiziksel olarak RAM'e alınıyor...", flush=True)
    spec = importlib.util.spec_from_file_location("DeepRFT_MIMO", file_path)
    DeepRFT_MIMO = importlib.util.module_from_spec(spec)
    sys.modules["DeepRFT_MIMO"] = DeepRFT_MIMO
    spec.loader.exec_module(DeepRFT_MIMO)

    import inspect
    DeepRFT_bulundu = None
    for isim, obj in inspect.getmembers(DeepRFT_MIMO, inspect.isclass):
        if 'DeepRFT' in isim:
            DeepRFT_bulundu = obj
            print(f" 🎯 Nokta Atışı Başarılı! Sınıf bulundu: {isim}", flush=True)
            break

    if DeepRFT_bulundu is None:
        raise Exception("DeepRFT sınıfı bulunamadı!")

    import __main__
    __main__.DeepRFT = DeepRFT_bulundu
    print(" 🟢 [BAŞARILI] Orijinal SOTA model Python çekirdeğine MÜHÜRLENDİ!", flush=True)

except Exception as e:
    print(f" ❌ [Kritik Sistem Hatası] {e}", flush=True)
# Out:
# ⚡ [Sistem] DeepRFT orijinal commit (Dec 5, 2021) yapılandırılıyor...
#  📥 DeepRFT reposu klonlanıyor...
#  🔍 DeepRFT_MIMO.py modülü fiziksel olarak RAM'e alınıyor...
#  🎯 Nokta Atışı Başarılı! Sınıf bulundu: DeepRFT
#  🟢 [BAŞARILI] Orijinal SOTA model Python çekirdeğine MÜHÜRLENDİ!

# %%
# ==============================================================================
# ✈️ PRE-FLIGHT CHECK (Senkronizasyon Korumalı)
# ==============================================================================
import torch
import os
import time

weights_path = "/content/drive/MyDrive/Spikedge_Staj/Deblurring/model_GoPro.pth"

print("🔍 [Pre-Flight Check] Drive senkronizasyonu bekleniyor...", flush=True)

# Drive senkronizasyonu için kısa bir bekleme ve kontrol döngüsü
for i in range(10):
    if os.path.exists(weights_path):
        print(f" ✅ Dosya algılandı! Boyut: {os.path.getsize(weights_path) / (1024*1024):.2f} MB", flush=True)
        break
    time.sleep(2)

try:
    import __main__
    if not hasattr(__main__, 'DeepRFT'):
        raise Exception("DeepRFT modeli RAM'de bulunamadı! Lütfen önce Hücre 2.5'i çalıştırın.")

    test_model = __main__.DeepRFT()

    if not os.path.exists(weights_path):
        raise Exception(f"Ağırlık dosyası hâl่ะ senkronize olmadı: {weights_path}")

    checkpoint = torch.load(weights_path, map_location="cpu", weights_only=False)
    raw_state_dict = checkpoint.get("state_dict", checkpoint.get("model", checkpoint))

    clean_state_dict = {k.replace('module.', ''): v for k, v in raw_state_dict.items()}

    test_model.load_state_dict(clean_state_dict, strict=True)

    print("\n" + "🟢"*30, flush=True)
    print(" 🎉 MÜKEMMEL! Altın madeni ağırlık dosyası model mimarisiyle %100 UYUMLU!", flush=True)
    print("🟢"*30, flush=True)

except Exception as e:
    print(f"\n❌ [HATA]:\n{e}", flush=True)
# Out:
# 🔍 [Pre-Flight Check] Drive senkronizasyonu bekleniyor...
#  ✅ Dosya algılandı! Boyut: 41.51 MB
#
# 🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢
#  🎉 MÜKEMMEL! Altın madeni ağırlık dosyası model mimarisiyle %100 UYUMLU!
# 🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢🟢

# %%
# ==============================================================================
# 🚀 HÜCRE 3: BATCH PIPELINE V7 (STAGE SWAP ABLATION: STAB -> DEBLUR)
# ==============================================================================
import os
import time
import cv2
import glob
import numpy as np
import torch
import gc
import sys
import subprocess
import shutil
import configparser

print("🛡️ [Ablation Pipeline] STAGE SWAP AKTİF: Önce Stabilizasyon, Sonra Deblurring...", flush=True)

# ⚠️ Akıllı Devam (Smart Resume)
FORCE_CLEAN_RUN = False

subprocess.run([sys.executable, "-m", "pip", "install", "thop", "loguru", "lap", "cython_bbox", "faiss-gpu", "filterpy", "scipy", "-q"])

os.environ["OMP_NUM_THREADS"] = "1"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
cv2.setNumThreads(1)

def aggressive_ram_purge():
    gc.collect()
    if torch.cuda.is_available(): torch.cuda.empty_cache()

def get_sequence_fps(seq_base_path):
    ini_path = os.path.join(seq_base_path, "seqinfo.ini")
    if os.path.exists(ini_path):
        config = configparser.ConfigParser()
        config.read(ini_path)
        try: return float(config['Sequence']['frameRate'])
        except Exception: pass
    return 30.0

def check_video_health(path):
    if not os.path.exists(path) or os.path.getsize(path) < 10000: return False
    cap = cv2.VideoCapture(path)
    frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    cap.release()
    return frames > 10

def safe_drive_mirror(local_path, drive_path, stage_name):
    print(f" 🎬 [{stage_name}] H.264 (YUV420P) formatında renk korumalı mühürleniyor...", flush=True)
    os.makedirs(os.path.dirname(drive_path), exist_ok=True)
    cmd = f"ffmpeg -y -i '{local_path}' -c:v libx264 -pix_fmt yuv420p -preset fast -crf 17 '{drive_path}'"
    res = subprocess.run(cmd, shell=True, capture_output=True, text=True)

    if res.returncode != 0 or not os.path.exists(drive_path) or not check_video_health(drive_path):
        shutil.copy(local_path, drive_path)

    time.sleep(1)
    if check_video_health(drive_path):
        size_mb = os.path.getsize(drive_path) / (1024 * 1024)
        print(f" ✅ [{stage_name}] Mühürleme Başarılı! ({size_mb:.2f} MB)", flush=True)
    else:
        print(f" ❌ [{stage_name}] HATA: Drive dizinine sağlıklı yazılamadı!", flush=True)

# ==============================================================================
# 🎛️ MODÜL 1 & 2 FONKSİYONLARI (Aynı algoritmalar, farklı sıra)
# ==============================================================================
def load_deblur_model(weights_path: str, device: str = "cuda"):
    device = torch.device(device if torch.cuda.is_available() else "cpu")
    PROJECT_ROOT = "/content/drive/MyDrive/Spikedge_Staj"
    if not os.path.exists(weights_path) and not os.path.isabs(weights_path):
        weights_path = os.path.join(PROJECT_ROOT, "Deblurring", weights_path)

    try:
        import __main__
        model = __main__.DeepRFT()
        if os.path.exists(weights_path):
            checkpoint = torch.load(weights_path, map_location=device, weights_only=False)
            state_dict = checkpoint.get("state_dict", checkpoint.get("model", checkpoint))
            clean_state_dict = {k.replace('module.', ''): v for k, v in state_dict.items()}
            model.load_state_dict(clean_state_dict, strict=True)
        model.to(device); model.eval()
        return model
    except Exception: return None

def run_deblurring(frames: list, model, device: str = "cuda") -> list:
    frames_arr = np.array(frames)
    deblurred = []
    if model is None: return frames_arr.tolist()
    device = torch.device(device if torch.cuda.is_available() else "cpu")
    for img in frames_arr:
        inp = torch.from_numpy(img).float().permute(2, 0, 1).unsqueeze(0) / 255.0
        inp = inp.to(device)
        with torch.no_grad():
            out = model(inp)
            if isinstance(out, (list, tuple)): out = out[0]
        out = torch.clamp(out, 0.0, 1.0)
        out_np = (out.squeeze(0).permute(1, 2, 0).cpu().numpy() * 255.0).astype(np.uint8)
        deblurred.append(out_np)
    return deblurred

def movingAverage(curve, radius):
    window_size = 2 * radius + 1
    f = np.ones(window_size) / window_size
    curve_pad = np.pad(curve, (radius, radius), mode='edge')
    return np.convolve(curve_pad, f, mode='same')[radius:-radius]

def smooth(trajectory, smoothing_radius):
    smoothed_trajectory = np.copy(trajectory)
    for i in range(3): smoothed_trajectory[:, i] = movingAverage(trajectory[:, i], radius=smoothing_radius)
    return smoothed_trajectory

def run_lightstab(input_path, output_path, seq_fps, transform_save_path, smoothing_radius=30):
    cap = cv2.VideoCapture(input_path)
    n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    w, h = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), seq_fps, (w, h))
    _, prev = cap.read()
    if prev is None: cap.release(); out.release(); return
    prev_gray = cv2.cvtColor(prev, cv2.COLOR_BGR2GRAY)
    transforms = np.zeros((max(1, n_frames-1), 3), np.float32)

    for i in range(min(n_frames-2, len(transforms))):
        prev_pts = cv2.goodFeaturesToTrack(prev_gray, maxCorners=200, qualityLevel=0.01, minDistance=30, blockSize=3)
        success, curr = cap.read()
        if not success: break
        curr_gray = cv2.cvtColor(curr, cv2.COLOR_BGR2GRAY)
        if prev_pts is not None:
            curr_pts, status, err = cv2.calcOpticalFlowPyrLK(prev_gray, curr_gray, prev_pts, None)
            idx = np.where(status==1)[0]
            if len(idx) > 10:
                prev_pts, curr_pts = prev_pts[idx], curr_pts[idx]
                m, _ = cv2.estimateAffinePartial2D(prev_pts, curr_pts)
                dx, dy, da = (m[0,2], m[1,2], np.arctan2(m[1,0], m[0,0])) if m is not None else (0, 0, 0)
            else: dx, dy, da = 0, 0, 0
        else: dx, dy, da = 0, 0, 0
        transforms[i] = [dx, dy, da]
        prev_gray = curr_gray

    trajectory = np.cumsum(transforms, axis=0)
    transforms_smooth = transforms + (smooth(trajectory, smoothing_radius) - trajectory)
    np.save(transform_save_path, transforms_smooth)

    cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
    for i in range(n_frames-1):
        success, frame = cap.read()
        if not success: break
        dx, dy, da = transforms_smooth[min(i, len(transforms_smooth)-1)]
        m = np.zeros((2,3), np.float32)
        m[0,0], m[0,1], m[0,2] = np.cos(da), -np.sin(da), dx
        m[1,0], m[1,1], m[1,2] = np.sin(da), np.cos(da), dy
        out.write(cv2.warpAffine(frame, m, (w,h)))
    cap.release(); out.release()

def restore_coordinates(input_txt, output_txt, transforms_path):
    if not os.path.exists(transforms_path) or not os.path.exists(input_txt):
        shutil.copy(input_txt, output_txt)
        return
    transforms_smooth = np.load(transforms_path)
    restored_lines = []
    with open(input_txt, 'r') as f:
        for line in f:
            parts = line.strip().replace(',', ' ').split()
            if len(parts) < 6: continue
            frame_id = int(float(parts[0]))
            if frame_id == 0:
                frame_id = 1
                parts[0] = str(frame_id)
            idx = max(0, min(frame_id - 1, len(transforms_smooth) - 1))
            dx, dy, da = transforms_smooth[idx]
            parts[2] = f"{float(parts[2]) - dx:.2f}"
            parts[3] = f"{float(parts[3]) - dy:.2f}"
            restored_lines.append(",".join(parts))
    with open(output_txt, 'w') as f: f.write("\n".join(restored_lines) + "\n")

# ==============================================================================
# 🔄 YENİ MİMARİ: DİNAMİK DÖNGÜ (ÖNCE STAB, SONRA DEBLUR)
# ==============================================================================
PROJECT_ROOT = "/content/drive/MyDrive/Spikedge_Staj"
# ⚠️ Çıktılar eski veriyi ezmemek için SWAP klasörlerine yönlendirildi:
DRIVE_INTERMEDIATE = os.path.join(PROJECT_ROOT, "Tracking/intermediate_swap")
DRIVE_OUTPUT = os.path.join(PROJECT_ROOT, "Tracking/output_tracks_swap")
DRIVE_TELEMETRY = os.path.join(PROJECT_ROOT, "Tracking/telemetry_swap")
DRIVE_INPUT_VIDEOS = os.path.join(PROJECT_ROOT, "Tracking/input_videos_train")
LOCAL_DIR = "/content/local_processing"

for d in [LOCAL_DIR, DRIVE_INTERMEDIATE, DRIVE_OUTPUT, DRIVE_TELEMETRY, DRIVE_INPUT_VIDEOS]:
    os.makedirs(d, exist_ok=True)

sequences = [
    "MOT17-02-FRCNN", "MOT17-04-FRCNN", "MOT17-05-FRCNN",
    "MOT17-09-FRCNN", "MOT17-10-FRCNN", "MOT17-11-FRCNN", "MOT17-13-FRCNN"
]

hybris_dir = "/content/HybridSORT"
if not os.path.exists(hybris_dir): subprocess.run(["git", "clone", "https://github.com/ymzis69/HybridSORT.git", hybris_dir])
os.chdir(hybris_dir)
# Yamalar (NumPy & PyTorch)
for py_f in glob.glob("**/*.py", recursive=True):
    try:
        with open(py_f, 'r', encoding='utf-8') as f: content = f.read()
        if "from collections import " in content or "trk[:] =" in content or "torch.load(" in content:
            content = content.replace("from collections import Mapping, OrderedDict", "from collections.abc import Mapping\nfrom collections import OrderedDict").replace("from collections import Mapping", "from collections.abc import Mapping").replace("from collections import Iterable", "from collections.abc import Iterable").replace("from torch._six import string_classes", "string_classes = (str, bytes)").replace("from torch._six import int_classes", "int_classes = int")
            content = content.replace("trk[:] = [pos[0][0], pos[0][1], pos[0][2], pos[0][3], kalman_score, simple_score[0]]", "p_flat = np.atleast_1d(pos[0]).flatten(); s_flat = np.atleast_1d(simple_score).flatten(); trk[:] = [float(p_flat[0]), float(p_flat[1]), float(p_flat[2]), float(p_flat[3]), float(kalman_score), float(s_flat[0])]")
            content = content.replace('torch.load(ckpt_file, map_location="cpu")', 'torch.load(ckpt_file, map_location="cpu", weights_only=False)')
            with open(py_f, 'w', encoding='utf-8') as f: f.write(content)
    except Exception: pass

local_ckpt = os.path.join(hybris_dir, "weights/yolox_x.pth")
if not os.path.exists(local_ckpt):
    os.makedirs(os.path.dirname(local_ckpt), exist_ok=True)
    os.system(f"curl -L -# -o {local_ckpt} https://github.com/ifzhang/ByteTrack/releases/download/v0.1_supp/yolox_x.pth")

exp_file = "exps/example/mot/yolox_x_mix_det_hybrid_sort.py"
if not os.path.exists(exp_file): exp_file = "exps/example/mot/yolox_x_mix_det.py"

for seq_name in sequences:
    print(f"\n" + "═"*70, flush=True)
    print(f"🎯 İŞLENEN SEKANS (STAGE SWAP): {seq_name}", flush=True)
    print(f"═"*70, flush=True)

    found_paths = glob.glob(f"/content/drive/MyDrive/**/{seq_name}/img1", recursive=True)
    if not found_paths:
        found_paths = glob.glob(f"/content/drive/MyDrive/**/{seq_name}", recursive=True)
        if found_paths and not os.path.exists(os.path.join(found_paths[0], "img1")): seq_base_path = found_paths[0]
        else: print(f" ⚠️ Uyarı: {seq_name} sekansı bulunamadı!", flush=True); continue
    else: seq_base_path = os.path.dirname(found_paths[0])

    seq_fps = get_sequence_fps(seq_base_path)
    image_files = sorted(glob.glob(os.path.join(seq_base_path, "img1", "*.jpg")))
    if not image_files: continue

    temp_source = os.path.join(LOCAL_DIR, f"{seq_name}_source.mp4")
    D_INPUT = os.path.join(DRIVE_INPUT_VIDEOS, f"{seq_name}_raw_input.mp4")

    # ⚠️ DİKKAT: STAGE İSİMLERİ VE SIRALAMASI DEĞİŞTİ
    L_STAGE1 = os.path.join(LOCAL_DIR, f"stage1_stabilized_{seq_name}.mp4")
    D_STAGE1 = os.path.join(DRIVE_INTERMEDIATE, f"stage1_stabilized_{seq_name}.mp4")

    L_STAGE2 = os.path.join(LOCAL_DIR, f"stage2_deblurred_{seq_name}.mp4")
    D_STAGE2 = os.path.join(DRIVE_INTERMEDIATE, f"stage2_deblurred_{seq_name}.mp4")

    D_STAGE3 = os.path.join(DRIVE_OUTPUT, f"final_tracked_{seq_name}.mp4")
    MATRIX_PATH = os.path.join(DRIVE_INTERMEDIATE, f"{seq_name}_transforms.npy")

    # [GİRDİ VİDEOSU HAZIRLIĞI]
    if not FORCE_CLEAN_RUN and check_video_health(D_INPUT):
        if not os.path.exists(temp_source): shutil.copy(D_INPUT, temp_source)
    else:
        sample_img = cv2.imread(image_files[0])
        writer = cv2.VideoWriter(temp_source, cv2.VideoWriter_fourcc(*'mp4v'), seq_fps, (sample_img.shape[1], sample_img.shape[0]))
        for img_path in image_files: writer.write(cv2.imread(img_path))
        writer.release()
        safe_drive_mirror(temp_source, D_INPUT, f"Raw Input ({seq_name})")

    # 🚀 YENİ STAGE 1: LIGHTSTAB (STABILIZASYON)
    if not FORCE_CLEAN_RUN and check_video_health(D_STAGE1) and os.path.exists(MATRIX_PATH):
        if not os.path.exists(L_STAGE1): shutil.copy(D_STAGE1, L_STAGE1)
        print(" ⏭️ [Stage 1 - STAB] Atlanıyor (Matrisler Bulundu).", flush=True)
    else:
        print(f" 🚀 [Stage 1 - STAB] LightStab Çalıştırılıyor (Ham Video Üzerinde)...", flush=True)
        run_lightstab(temp_source, L_STAGE1, seq_fps, transform_save_path=MATRIX_PATH, smoothing_radius=30)
        safe_drive_mirror(L_STAGE1, D_STAGE1, f"Stage 1 Stab ({seq_name})")
    aggressive_ram_purge()

    # 🚀 YENİ STAGE 2: DEEPRFT (DEBLURRING)
    if not FORCE_CLEAN_RUN and check_video_health(D_STAGE2):
        if not os.path.exists(L_STAGE2): shutil.copy(D_STAGE2, L_STAGE2)
        print(" ⏭️ [Stage 2 - DEBLUR] Atlanıyor.", flush=True)
    else:
        print(f" 🚀 [Stage 2 - DEBLUR] DeepRFT SOTA Başlatılıyor (Sarsıntısı Alınmış Video Üzerinde)...", flush=True)
        m1 = load_deblur_model("model_GoPro.pth", device="cuda")
        cap = cv2.VideoCapture(L_STAGE1)
        frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        writer_s1 = cv2.VideoWriter(L_STAGE2, cv2.VideoWriter_fourcc(*'mp4v'), seq_fps, (frame_width, frame_height))
        chunk = []
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret: break
            chunk.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            if len(chunk) >= 100:
                for f in run_deblurring(chunk, m1, device="cuda"): writer_s1.write(cv2.cvtColor(f, cv2.COLOR_RGB2BGR))
                chunk.clear(); aggressive_ram_purge()
        if chunk:
            for f in run_deblurring(chunk, m1, device="cuda"): writer_s1.write(cv2.cvtColor(f, cv2.COLOR_RGB2BGR))
        cap.release(); writer_s1.release()
        try: del m1
        except: pass
        aggressive_ram_purge()
        safe_drive_mirror(L_STAGE2, D_STAGE2, f"Stage 2 Deblur ({seq_name})")

    # 🚀 STAGE 3: HYBRIDSORT (TAKİP)
    if not FORCE_CLEAN_RUN and check_video_health(D_STAGE3) and os.path.exists(os.path.join(DRIVE_TELEMETRY, f"{seq_name}.txt")):
        print(" ⏭️ [Stage 3] Final Video hazır, atlanıyor.", flush=True)
    else:
        print(f" 🚀 [Stage 3] Hybrid-SORT Takip Motoru...", flush=True)
        sota_out_dir = f"/content/sota_run_out_{seq_name}"
        os.makedirs(sota_out_dir, exist_ok=True)
        # ⚠️ Takip motoruna artık Stage 2 (Deblurred) videosu veriliyor
        cmd = [sys.executable, f"{hybris_dir}/tools/demo_track.py", "--demo_type", "video", "-f", exp_file, "-c", local_ckpt, "--path", L_STAGE2, "--output_dir", sota_out_dir, "--device", "gpu", "--fp16", "--fuse", "--save_result"]
        env = os.environ.copy(); env["PYTHONPATH"] = hybris_dir
        process = subprocess.Popen(cmd, env=env, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
        for line in process.stdout:
            if "Processing frame" in line or "save results to" in line: sys.stdout.write(line); sys.stdout.flush()
        process.wait()

        if process.returncode != 0: print(f" ❌ {seq_name} Hybrid-SORT hatası!", flush=True); continue

        txt_files = glob.glob(os.path.join(sota_out_dir, "**/track_vis/*.txt"), recursive=True) + glob.glob("/content/HybridSORT/YOLOX_outputs/**/track_vis/*.txt", recursive=True)
        if txt_files:
            latest_txt = max(txt_files, key=os.path.getmtime)
            final_telemetry_path = os.path.join(DRIVE_TELEMETRY, f"{seq_name}.txt")
            restore_coordinates(latest_txt, final_telemetry_path, MATRIX_PATH)
            print(f" 💾 [Telemetri] Düzeltilmiş Koordinatlar Drive'a kilitlendi: {seq_name}.txt", flush=True)
        else: continue

        print(f" 🎨 [Stage 3.5] Render Stüdyosu...", flush=True)
        tracking_data = {}
        with open(final_telemetry_path, 'r') as f:
            for line in f:
                parts = line.strip().replace(',', ' ').split()
                if len(parts) < 6: continue
                frame_id = int(float(parts[0]))
                track_id = int(float(parts[1]))
                if frame_id not in tracking_data: tracking_data[frame_id] = []
                tracking_data[frame_id].append((track_id, float(parts[2]), float(parts[3]), float(parts[4]), float(parts[5])))

        cap = cv2.VideoCapture(temp_source)
        local_rendered = os.path.join(LOCAL_DIR, f"rendered_{seq_name}.mp4")
        writer = cv2.VideoWriter(local_rendered, cv2.VideoWriter_fourcc(*'mp4v'), seq_fps, (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

        np.random.seed(42); colors = {}
        f_idx = 1
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret: break
            if f_idx in tracking_data:
                for tid, l, t, wd, ht in tracking_data[f_idx]:
                    x1, y1, x2, y2 = int(l), int(t), int(l + wd), int(t + ht)
                    if tid not in colors: colors[tid] = (int(np.random.randint(50, 255)), int(np.random.randint(50, 255)), int(np.random.randint(50, 255)))
                    cv2.rectangle(frame, (x1, y1), (x2, y2), colors[tid], 2)
                    label = f"ID: {tid}"
                    (tw, th), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 2)
                    cv2.rectangle(frame, (x1, y1 - 18), (x1 + tw + 4, y1), colors[tid], -1)
                    cv2.putText(frame, label, (x1 + 2, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
            writer.write(frame); f_idx += 1
        cap.release(); writer.release()
        safe_drive_mirror(local_rendered, D_STAGE3, f"Final Tracked ({seq_name})")
        aggressive_ram_purge()

os.chdir("/content")
print("\n" + "🏆"*35, flush=True)
print(" 🎉 STAGE SWAP DENEYİ (STAB -> DEBLUR) MÜHÜRLENDİ! 🎉", flush=True)
print("🏆"*35, flush=True)
# Out:
# 🛡️ [Ablation Pipeline] STAGE SWAP AKTİF: Önce Stabilizasyon, Sonra Deblurring...
#
# ══════════════════════════════════════════════════════════════════════
# 🎯 İŞLENEN SEKANS (STAGE SWAP): MOT17-02-FRCNN
# ══════════════════════════════════════════════════════════════════════
#  🚀 [Stage 1 - STAB] LightStab Çalıştırılıyor (Ham Video Üzerinde)...
#  🎬 [Stage 1 Stab (MOT17-02-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 1 Stab (MOT17-02-FRCNN)] Mühürleme Başarılı! (35.14 MB)
#  🚀 [Stage 2 - DEBLUR] DeepRFT SOTA Başlatılıyor (Sarsıntısı Alınmış Video Üzerinde)...
#  🎬 [Stage 2 Deblur (MOT17-02-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 2 Deblur (MOT17-02-FRCNN)] Mühürleme Başarılı! (35.17 MB)
#  🚀 [Stage 3] Hybrid-SORT Takip Motoru...
# 2026-08-04 16:26:35.049 | INFO     | __main__:imageflow_demo:240 - Processing frame 0 (100000.00 fps)
# 2026-08-04 16:26:39.705 | INFO     | __main__:imageflow_demo:240 - Processing frame 20 (8.33 fps)
# 2026-08-04 16:26:43.841 | INFO     | __main__:imageflow_demo:240 - Processing frame 40 (9.36 fps)
# 2026-08-04 16:26:48.658 | INFO     | __main__:imageflow_demo:240 - Processing frame 60 (9.61 fps)
# 2026-08-04 16:26:52.589 | INFO     | __main__:imageflow_demo:240 - Processing frame 80 (9.85 fps)
# 2026-08-04 16:26:56.539 | INFO     | __main__:imageflow_demo:240 - Processing frame 100 (9.98 fps)
# 2026-08-04 16:27:01.328 | INFO     | __main__:imageflow_demo:240 - Processing frame 120 (9.95 fps)
# 2026-08-04 16:27:05.627 | INFO     | __main__:imageflow_demo:240 - Processing frame 140 (9.98 fps)
# 2026-08-04 16:27:09.692 | INFO     | __main__:imageflow_demo:240 - Processing frame 160 (9.99 fps)
# 2026-08-04 16:27:14.221 | INFO     | __main__:imageflow_demo:240 - Processing frame 180 (9.96 fps)
# 2026-08-04 16:27:18.877 | INFO     | __main__:imageflow_demo:240 - Processing frame 200 (9.93 fps)
# 2026-08-04 16:27:22.996 | INFO     | __main__:imageflow_demo:240 - Processing frame 220 (9.92 fps)
# 2026-08-04 16:27:27.314 | INFO     | __main__:imageflow_demo:240 - Processing frame 240 (9.91 fps)
# 2026-08-04 16:27:32.300 | INFO     | __main__:imageflow_demo:240 - Processing frame 260 (9.88 fps)
# 2026-08-04 16:27:36.482 | INFO     | __main__:imageflow_demo:240 - Processing frame 280 (9.89 fps)
# 2026-08-04 16:27:40.670 | INFO     | __main__:imageflow_demo:240 - Processing frame 300 (9.91 fps)
# 2026-08-04 16:27:45.742 | INFO     | __main__:imageflow_demo:240 - Processing frame 320 (9.88 fps)
# 2026-08-04 16:27:49.995 | INFO     | __main__:imageflow_demo:240 - Processing frame 340 (9.89 fps)
# 2026-08-04 16:27:54.160 | INFO     | __main__:imageflow_demo:240 - Processing frame 360 (9.90 fps)
# 2026-08-04 16:27:58.925 | INFO     | __main__:imageflow_demo:240 - Processing frame 380 (9.87 fps)
# 2026-08-04 16:28:03.504 | INFO     | __main__:imageflow_demo:240 - Processing frame 400 (9.87 fps)
# 2026-08-04 16:28:07.688 | INFO     | __main__:imageflow_demo:240 - Processing frame 420 (9.87 fps)
# 2026-08-04 16:28:12.239 | INFO     | __main__:imageflow_demo:240 - Processing frame 440 (9.85 fps)
# 2026-08-04 16:28:17.068 | INFO     | __main__:imageflow_demo:240 - Processing frame 460 (9.82 fps)
# 2026-08-04 16:28:21.227 | INFO     | __main__:imageflow_demo:240 - Processing frame 480 (9.82 fps)
# 2026-08-04 16:28:25.416 | INFO     | __main__:imageflow_demo:240 - Processing frame 500 (9.82 fps)
# 2026-08-04 16:28:30.390 | INFO     | __main__:imageflow_demo:240 - Processing frame 520 (9.80 fps)
# 2026-08-04 16:28:34.628 | INFO     | __main__:imageflow_demo:240 - Processing frame 540 (9.81 fps)
# 2026-08-04 16:28:38.810 | INFO     | __main__:imageflow_demo:240 - Processing frame 560 (9.81 fps)
# 2026-08-04 16:28:43.814 | INFO     | __main__:imageflow_demo:240 - Processing frame 580 (9.79 fps)
# 2026-08-04 16:28:47.752 | INFO     | __main__:imageflow_demo:279 - save results to ./YOLOX_outputs/yolox_x_mix_det_hybrid_sort/False/track_vis/2026_08_04_16_26_35.txt
#  💾 [Telemetri] Düzeltilmiş Koordinatlar Drive'a kilitlendi: MOT17-02-FRCNN.txt
#  🎨 [Stage 3.5] Render Stüdyosu...
#  🎬 [Final Tracked (MOT17-02-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Final Tracked (MOT17-02-FRCNN)] Mühürleme Başarılı! (37.61 MB)
#
# ══════════════════════════════════════════════════════════════════════
# 🎯 İŞLENEN SEKANS (STAGE SWAP): MOT17-04-FRCNN
# ══════════════════════════════════════════════════════════════════════
#  🚀 [Stage 1 - STAB] LightStab Çalıştırılıyor (Ham Video Üzerinde)...
#  🎬 [Stage 1 Stab (MOT17-04-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 1 Stab (MOT17-04-FRCNN)] Mühürleme Başarılı! (42.36 MB)
#  🚀 [Stage 2 - DEBLUR] DeepRFT SOTA Başlatılıyor (Sarsıntısı Alınmış Video Üzerinde)...
#  🎬 [Stage 2 Deblur (MOT17-04-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 2 Deblur (MOT17-04-FRCNN)] Mühürleme Başarılı! (42.50 MB)
#  🚀 [Stage 3] Hybrid-SORT Takip Motoru...
# 2026-08-04 17:22:05.359 | INFO     | __main__:imageflow_demo:240 - Processing frame 0 (100000.00 fps)
# 2026-08-04 17:22:09.817 | INFO     | __main__:imageflow_demo:240 - Processing frame 20 (8.95 fps)
# 2026-08-04 17:22:14.674 | INFO     | __main__:imageflow_demo:240 - Processing frame 40 (9.28 fps)
# 2026-08-04 17:22:18.839 | INFO     | __main__:imageflow_demo:240 - Processing frame 60 (9.50 fps)
# 2026-08-04 17:22:22.809 | INFO     | __main__:imageflow_demo:240 - Processing frame 80 (9.66 fps)
# 2026-08-04 17:22:27.229 | INFO     | __main__:imageflow_demo:240 - Processing frame 100 (9.73 fps)
# 2026-08-04 17:22:31.890 | INFO     | __main__:imageflow_demo:240 - Processing frame 120 (9.72 fps)
# 2026-08-04 17:22:36.069 | INFO     | __main__:imageflow_demo:240 - Processing frame 140 (9.75 fps)
# 2026-08-04 17:22:40.329 | INFO     | __main__:imageflow_demo:240 - Processing frame 160 (9.76 fps)
# 2026-08-04 17:22:45.223 | INFO     | __main__:imageflow_demo:240 - Processing frame 180 (9.73 fps)
# 2026-08-04 17:22:49.370 | INFO     | __main__:imageflow_demo:240 - Processing frame 200 (9.75 fps)
# 2026-08-04 17:22:53.540 | INFO     | __main__:imageflow_demo:240 - Processing frame 220 (9.77 fps)
# 2026-08-04 17:22:58.668 | INFO     | __main__:imageflow_demo:240 - Processing frame 240 (9.72 fps)
# 2026-08-04 17:23:02.887 | INFO     | __main__:imageflow_demo:240 - Processing frame 260 (9.73 fps)
# 2026-08-04 17:23:07.137 | INFO     | __main__:imageflow_demo:240 - Processing frame 280 (9.73 fps)
# 2026-08-04 17:23:12.001 | INFO     | __main__:imageflow_demo:240 - Processing frame 300 (9.70 fps)
# 2026-08-04 17:23:16.470 | INFO     | __main__:imageflow_demo:240 - Processing frame 320 (9.70 fps)
# 2026-08-04 17:23:20.697 | INFO     | __main__:imageflow_demo:240 - Processing frame 340 (9.71 fps)
# 2026-08-04 17:23:25.352 | INFO     | __main__:imageflow_demo:240 - Processing frame 360 (9.70 fps)
# 2026-08-04 17:23:29.995 | INFO     | __main__:imageflow_demo:240 - Processing frame 380 (9.68 fps)
# 2026-08-04 17:23:34.194 | INFO     | __main__:imageflow_demo:240 - Processing frame 400 (9.69 fps)
# 2026-08-04 17:23:38.638 | INFO     | __main__:imageflow_demo:240 - Processing frame 420 (9.68 fps)
# 2026-08-04 17:23:43.575 | INFO     | __main__:imageflow_demo:240 - Processing frame 440 (9.67 fps)
# 2026-08-04 17:23:47.775 | INFO     | __main__:imageflow_demo:240 - Processing frame 460 (9.68 fps)
# 2026-08-04 17:23:51.989 | INFO     | __main__:imageflow_demo:240 - Processing frame 480 (9.68 fps)
# 2026-08-04 17:23:57.219 | INFO     | __main__:imageflow_demo:240 - Processing frame 500 (9.66 fps)
# 2026-08-04 17:24:01.444 | INFO     | __main__:imageflow_demo:240 - Processing frame 520 (9.66 fps)
# 2026-08-04 17:24:05.705 | INFO     | __main__:imageflow_demo:240 - Processing frame 540 (9.66 fps)
# 2026-08-04 17:24:10.856 | INFO     | __main__:imageflow_demo:240 - Processing frame 560 (9.63 fps)
# 2026-08-04 17:24:15.172 | INFO     | __main__:imageflow_demo:240 - Processing frame 580 (9.63 fps)
# 2026-08-04 17:24:19.345 | INFO     | __main__:imageflow_demo:240 - Processing frame 600 (9.64 fps)
# 2026-08-04 17:24:24.051 | INFO     | __main__:imageflow_demo:240 - Processing frame 620 (9.63 fps)
# 2026-08-04 17:24:28.634 | INFO     | __main__:imageflow_demo:240 - Processing frame 640 (9.63 fps)
# 2026-08-04 17:24:32.784 | INFO     | __main__:imageflow_demo:240 - Processing frame 660 (9.63 fps)
# 2026-08-04 17:24:37.253 | INFO     | __main__:imageflow_demo:240 - Processing frame 680 (9.63 fps)
# 2026-08-04 17:24:42.192 | INFO     | __main__:imageflow_demo:240 - Processing frame 700 (9.62 fps)
# 2026-08-04 17:24:46.364 | INFO     | __main__:imageflow_demo:240 - Processing frame 720 (9.62 fps)
# 2026-08-04 17:24:50.513 | INFO     | __main__:imageflow_demo:240 - Processing frame 740 (9.62 fps)
# 2026-08-04 17:24:55.668 | INFO     | __main__:imageflow_demo:240 - Processing frame 760 (9.61 fps)
# 2026-08-04 17:24:59.799 | INFO     | __main__:imageflow_demo:240 - Processing frame 780 (9.62 fps)
# 2026-08-04 17:25:03.985 | INFO     | __main__:imageflow_demo:240 - Processing frame 800 (9.62 fps)
# 2026-08-04 17:25:08.872 | INFO     | __main__:imageflow_demo:240 - Processing frame 820 (9.62 fps)
# 2026-08-04 17:25:13.177 | INFO     | __main__:imageflow_demo:240 - Processing frame 840 (9.62 fps)
# 2026-08-04 17:25:17.320 | INFO     | __main__:imageflow_demo:240 - Processing frame 860 (9.62 fps)
# 2026-08-04 17:25:21.999 | INFO     | __main__:imageflow_demo:240 - Processing frame 880 (9.61 fps)
# 2026-08-04 17:25:26.604 | INFO     | __main__:imageflow_demo:240 - Processing frame 900 (9.61 fps)
# 2026-08-04 17:25:30.727 | INFO     | __main__:imageflow_demo:240 - Processing frame 920 (9.61 fps)
# 2026-08-04 17:25:35.118 | INFO     | __main__:imageflow_demo:240 - Processing frame 940 (9.61 fps)
# 2026-08-04 17:25:40.102 | INFO     | __main__:imageflow_demo:240 - Processing frame 960 (9.60 fps)
# 2026-08-04 17:25:44.286 | INFO     | __main__:imageflow_demo:240 - Processing frame 980 (9.60 fps)
# 2026-08-04 17:25:48.442 | INFO     | __main__:imageflow_demo:240 - Processing frame 1000 (9.61 fps)
# 2026-08-04 17:25:53.448 | INFO     | __main__:imageflow_demo:240 - Processing frame 1020 (9.59 fps)
# 2026-08-04 17:25:57.576 | INFO     | __main__:imageflow_demo:240 - Processing frame 1040 (9.60 fps)
# 2026-08-04 17:25:59.462 | INFO     | __main__:imageflow_demo:279 - save results to ./YOLOX_outputs/yolox_x_mix_det_hybrid_sort/False/track_vis/2026_08_04_17_22_05.txt
#  💾 [Telemetri] Düzeltilmiş Koordinatlar Drive'a kilitlendi: MOT17-04-FRCNN.txt
#  🎨 [Stage 3.5] Render Stüdyosu...
#  🎬 [Final Tracked (MOT17-04-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Final Tracked (MOT17-04-FRCNN)] Mühürleme Başarılı! (52.73 MB)
#
# ══════════════════════════════════════════════════════════════════════
# 🎯 İŞLENEN SEKANS (STAGE SWAP): MOT17-05-FRCNN
# ══════════════════════════════════════════════════════════════════════
#  🚀 [Stage 1 - STAB] LightStab Çalıştırılıyor (Ham Video Üzerinde)...
#  🎬 [Stage 1 Stab (MOT17-05-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 1 Stab (MOT17-05-FRCNN)] Mühürleme Başarılı! (14.46 MB)
#  🚀 [Stage 2 - DEBLUR] DeepRFT SOTA Başlatılıyor (Sarsıntısı Alınmış Video Üzerinde)...
#  🎬 [Stage 2 Deblur (MOT17-05-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 2 Deblur (MOT17-05-FRCNN)] Mühürleme Başarılı! (15.41 MB)
#  🚀 [Stage 3] Hybrid-SORT Takip Motoru...
# 2026-08-04 17:35:43.858 | INFO     | __main__:imageflow_demo:240 - Processing frame 0 (100000.00 fps)
# 2026-08-04 17:35:47.364 | INFO     | __main__:imageflow_demo:240 - Processing frame 20 (9.77 fps)
# 2026-08-04 17:35:50.501 | INFO     | __main__:imageflow_demo:240 - Processing frame 40 (10.56 fps)
# 2026-08-04 17:35:54.373 | INFO     | __main__:imageflow_demo:240 - Processing frame 60 (10.65 fps)
# 2026-08-04 17:35:57.622 | INFO     | __main__:imageflow_demo:240 - Processing frame 80 (10.79 fps)
# 2026-08-04 17:36:00.781 | INFO     | __main__:imageflow_demo:240 - Processing frame 100 (10.88 fps)
# 2026-08-04 17:36:03.951 | INFO     | __main__:imageflow_demo:240 - Processing frame 120 (10.95 fps)
# 2026-08-04 17:36:07.659 | INFO     | __main__:imageflow_demo:240 - Processing frame 140 (10.93 fps)
# 2026-08-04 17:36:11.153 | INFO     | __main__:imageflow_demo:240 - Processing frame 160 (10.93 fps)
# 2026-08-04 17:36:14.336 | INFO     | __main__:imageflow_demo:240 - Processing frame 180 (10.93 fps)
# 2026-08-04 17:36:17.431 | INFO     | __main__:imageflow_demo:240 - Processing frame 200 (10.96 fps)
# 2026-08-04 17:36:20.844 | INFO     | __main__:imageflow_demo:240 - Processing frame 220 (10.97 fps)
# 2026-08-04 17:36:24.490 | INFO     | __main__:imageflow_demo:240 - Processing frame 240 (10.96 fps)
# 2026-08-04 17:36:27.632 | INFO     | __main__:imageflow_demo:240 - Processing frame 260 (10.97 fps)
# 2026-08-04 17:36:30.760 | INFO     | __main__:imageflow_demo:240 - Processing frame 280 (10.99 fps)
# 2026-08-04 17:36:34.022 | INFO     | __main__:imageflow_demo:240 - Processing frame 300 (11.01 fps)
# 2026-08-04 17:36:37.812 | INFO     | __main__:imageflow_demo:240 - Processing frame 320 (10.99 fps)
# 2026-08-04 17:36:40.935 | INFO     | __main__:imageflow_demo:240 - Processing frame 340 (11.01 fps)
# 2026-08-04 17:36:44.024 | INFO     | __main__:imageflow_demo:240 - Processing frame 360 (11.04 fps)
# 2026-08-04 17:36:47.132 | INFO     | __main__:imageflow_demo:240 - Processing frame 380 (11.07 fps)
# 2026-08-04 17:36:50.987 | INFO     | __main__:imageflow_demo:240 - Processing frame 400 (11.06 fps)
# 2026-08-04 17:36:54.095 | INFO     | __main__:imageflow_demo:240 - Processing frame 420 (11.09 fps)
# 2026-08-04 17:36:57.165 | INFO     | __main__:imageflow_demo:240 - Processing frame 440 (11.12 fps)
# 2026-08-04 17:37:00.266 | INFO     | __main__:imageflow_demo:240 - Processing frame 460 (11.13 fps)
# 2026-08-04 17:37:03.950 | INFO     | __main__:imageflow_demo:240 - Processing frame 480 (11.14 fps)
# 2026-08-04 17:37:07.315 | INFO     | __main__:imageflow_demo:240 - Processing frame 500 (11.15 fps)
# 2026-08-04 17:37:10.321 | INFO     | __main__:imageflow_demo:240 - Processing frame 520 (11.17 fps)
# 2026-08-04 17:37:13.382 | INFO     | __main__:imageflow_demo:240 - Processing frame 540 (11.18 fps)
# 2026-08-04 17:37:16.727 | INFO     | __main__:imageflow_demo:240 - Processing frame 560 (11.18 fps)
# 2026-08-04 17:37:20.382 | INFO     | __main__:imageflow_demo:240 - Processing frame 580 (11.17 fps)
# 2026-08-04 17:37:23.507 | INFO     | __main__:imageflow_demo:240 - Processing frame 600 (11.18 fps)
# 2026-08-04 17:37:26.592 | INFO     | __main__:imageflow_demo:240 - Processing frame 620 (11.19 fps)
# 2026-08-04 17:37:29.707 | INFO     | __main__:imageflow_demo:240 - Processing frame 640 (11.20 fps)
# 2026-08-04 17:37:33.573 | INFO     | __main__:imageflow_demo:240 - Processing frame 660 (11.19 fps)
# 2026-08-04 17:37:36.635 | INFO     | __main__:imageflow_demo:240 - Processing frame 680 (11.20 fps)
# 2026-08-04 17:37:39.724 | INFO     | __main__:imageflow_demo:240 - Processing frame 700 (11.21 fps)
# 2026-08-04 17:37:42.848 | INFO     | __main__:imageflow_demo:240 - Processing frame 720 (11.21 fps)
# 2026-08-04 17:37:46.552 | INFO     | __main__:imageflow_demo:240 - Processing frame 740 (11.21 fps)
# 2026-08-04 17:37:49.875 | INFO     | __main__:imageflow_demo:240 - Processing frame 760 (11.21 fps)
# 2026-08-04 17:37:53.035 | INFO     | __main__:imageflow_demo:240 - Processing frame 780 (11.20 fps)
# 2026-08-04 17:37:56.168 | INFO     | __main__:imageflow_demo:240 - Processing frame 800 (11.20 fps)
# 2026-08-04 17:37:59.788 | INFO     | __main__:imageflow_demo:240 - Processing frame 820 (11.19 fps)
# 2026-08-04 17:38:02.661 | INFO     | __main__:imageflow_demo:279 - save results to ./YOLOX_outputs/yolox_x_mix_det_hybrid_sort/False/track_vis/2026_08_04_17_35_43.txt
#  💾 [Telemetri] Düzeltilmiş Koordinatlar Drive'a kilitlendi: MOT17-05-FRCNN.txt
#  🎨 [Stage 3.5] Render Stüdyosu...
#  🎬 [Final Tracked (MOT17-05-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Final Tracked (MOT17-05-FRCNN)] Mühürleme Başarılı! (19.10 MB)
#
# ══════════════════════════════════════════════════════════════════════
# 🎯 İŞLENEN SEKANS (STAGE SWAP): MOT17-09-FRCNN
# ══════════════════════════════════════════════════════════════════════
#  🚀 [Stage 1 - STAB] LightStab Çalıştırılıyor (Ham Video Üzerinde)...
#  🎬 [Stage 1 Stab (MOT17-09-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 1 Stab (MOT17-09-FRCNN)] Mühürleme Başarılı! (30.62 MB)
#  🚀 [Stage 2 - DEBLUR] DeepRFT SOTA Başlatılıyor (Sarsıntısı Alınmış Video Üzerinde)...
#  🎬 [Stage 2 Deblur (MOT17-09-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 2 Deblur (MOT17-09-FRCNN)] Mühürleme Başarılı! (31.66 MB)
#  🚀 [Stage 3] Hybrid-SORT Takip Motoru...
# 2026-08-04 18:04:34.996 | INFO     | __main__:imageflow_demo:240 - Processing frame 0 (100000.00 fps)
# 2026-08-04 18:04:39.981 | INFO     | __main__:imageflow_demo:240 - Processing frame 20 (9.30 fps)
# 2026-08-04 18:04:43.786 | INFO     | __main__:imageflow_demo:240 - Processing frame 40 (10.27 fps)
# 2026-08-04 18:04:47.538 | INFO     | __main__:imageflow_demo:240 - Processing frame 60 (10.63 fps)
# 2026-08-04 18:04:51.810 | INFO     | __main__:imageflow_demo:240 - Processing frame 80 (10.75 fps)
# 2026-08-04 18:04:55.807 | INFO     | __main__:imageflow_demo:240 - Processing frame 100 (10.88 fps)
# 2026-08-04 18:04:59.600 | INFO     | __main__:imageflow_demo:240 - Processing frame 120 (10.95 fps)
# 2026-08-04 18:05:03.501 | INFO     | __main__:imageflow_demo:240 - Processing frame 140 (11.00 fps)
# 2026-08-04 18:05:08.022 | INFO     | __main__:imageflow_demo:240 - Processing frame 160 (10.98 fps)
# 2026-08-04 18:05:11.912 | INFO     | __main__:imageflow_demo:240 - Processing frame 180 (10.98 fps)
# 2026-08-04 18:05:15.742 | INFO     | __main__:imageflow_demo:240 - Processing frame 200 (10.98 fps)
# 2026-08-04 18:05:20.231 | INFO     | __main__:imageflow_demo:240 - Processing frame 220 (10.95 fps)
# 2026-08-04 18:05:24.270 | INFO     | __main__:imageflow_demo:240 - Processing frame 240 (10.95 fps)
# 2026-08-04 18:05:28.034 | INFO     | __main__:imageflow_demo:240 - Processing frame 260 (10.97 fps)
# 2026-08-04 18:05:32.009 | INFO     | __main__:imageflow_demo:240 - Processing frame 280 (10.98 fps)
# 2026-08-04 18:05:36.430 | INFO     | __main__:imageflow_demo:240 - Processing frame 300 (10.97 fps)
# 2026-08-04 18:05:40.242 | INFO     | __main__:imageflow_demo:240 - Processing frame 320 (10.98 fps)
# 2026-08-04 18:05:44.072 | INFO     | __main__:imageflow_demo:240 - Processing frame 340 (10.99 fps)
# 2026-08-04 18:05:48.516 | INFO     | __main__:imageflow_demo:240 - Processing frame 360 (10.98 fps)
# 2026-08-04 18:05:52.356 | INFO     | __main__:imageflow_demo:240 - Processing frame 380 (10.99 fps)
# 2026-08-04 18:05:56.060 | INFO     | __main__:imageflow_demo:240 - Processing frame 400 (11.01 fps)
# 2026-08-04 18:05:59.996 | INFO     | __main__:imageflow_demo:240 - Processing frame 420 (11.02 fps)
# 2026-08-04 18:06:04.376 | INFO     | __main__:imageflow_demo:240 - Processing frame 440 (11.02 fps)
# 2026-08-04 18:06:08.165 | INFO     | __main__:imageflow_demo:240 - Processing frame 460 (11.03 fps)
# 2026-08-04 18:06:11.917 | INFO     | __main__:imageflow_demo:240 - Processing frame 480 (11.03 fps)
# 2026-08-04 18:06:16.274 | INFO     | __main__:imageflow_demo:240 - Processing frame 500 (11.03 fps)
# 2026-08-04 18:06:20.186 | INFO     | __main__:imageflow_demo:240 - Processing frame 520 (11.03 fps)
# 2026-08-04 18:06:20.923 | INFO     | __main__:imageflow_demo:279 - save results to ./YOLOX_outputs/yolox_x_mix_det_hybrid_sort/False/track_vis/2026_08_04_18_04_34.txt
#  💾 [Telemetri] Düzeltilmiş Koordinatlar Drive'a kilitlendi: MOT17-09-FRCNN.txt
#  🎨 [Stage 3.5] Render Stüdyosu...
#  🎬 [Final Tracked (MOT17-09-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Final Tracked (MOT17-09-FRCNN)] Mühürleme Başarılı! (34.15 MB)
#
# ══════════════════════════════════════════════════════════════════════
# 🎯 İŞLENEN SEKANS (STAGE SWAP): MOT17-10-FRCNN
# ══════════════════════════════════════════════════════════════════════
#  🚀 [Stage 1 - STAB] LightStab Çalıştırılıyor (Ham Video Üzerinde)...
#  🎬 [Stage 1 Stab (MOT17-10-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 1 Stab (MOT17-10-FRCNN)] Mühürleme Başarılı! (38.08 MB)
#  🚀 [Stage 2 - DEBLUR] DeepRFT SOTA Başlatılıyor (Sarsıntısı Alınmış Video Üzerinde)...
#  🎬 [Stage 2 Deblur (MOT17-10-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 2 Deblur (MOT17-10-FRCNN)] Mühürleme Başarılı! (39.95 MB)
#  🚀 [Stage 3] Hybrid-SORT Takip Motoru...
# 2026-08-04 18:40:20.871 | INFO     | __main__:imageflow_demo:240 - Processing frame 0 (100000.00 fps)
# 2026-08-04 18:40:25.455 | INFO     | __main__:imageflow_demo:240 - Processing frame 20 (9.52 fps)
# 2026-08-04 18:40:29.895 | INFO     | __main__:imageflow_demo:240 - Processing frame 40 (10.01 fps)
# 2026-08-04 18:40:33.772 | INFO     | __main__:imageflow_demo:240 - Processing frame 60 (10.28 fps)
# 2026-08-04 18:40:37.664 | INFO     | __main__:imageflow_demo:240 - Processing frame 80 (10.42 fps)
# 2026-08-04 18:40:42.341 | INFO     | __main__:imageflow_demo:240 - Processing frame 100 (10.42 fps)
# 2026-08-04 18:40:46.186 | INFO     | __main__:imageflow_demo:240 - Processing frame 120 (10.51 fps)
# 2026-08-04 18:40:50.023 | INFO     | __main__:imageflow_demo:240 - Processing frame 140 (10.56 fps)
# 2026-08-04 18:40:54.311 | INFO     | __main__:imageflow_demo:240 - Processing frame 160 (10.57 fps)
# 2026-08-04 18:40:58.498 | INFO     | __main__:imageflow_demo:240 - Processing frame 180 (10.57 fps)
# 2026-08-04 18:41:02.382 | INFO     | __main__:imageflow_demo:240 - Processing frame 200 (10.59 fps)
# 2026-08-04 18:41:06.385 | INFO     | __main__:imageflow_demo:240 - Processing frame 220 (10.58 fps)
# 2026-08-04 18:41:10.967 | INFO     | __main__:imageflow_demo:240 - Processing frame 240 (10.56 fps)
# 2026-08-04 18:41:14.822 | INFO     | __main__:imageflow_demo:240 - Processing frame 260 (10.58 fps)
# 2026-08-04 18:41:18.655 | INFO     | __main__:imageflow_demo:240 - Processing frame 280 (10.60 fps)
# 2026-08-04 18:41:23.198 | INFO     | __main__:imageflow_demo:240 - Processing frame 300 (10.59 fps)
# 2026-08-04 18:41:27.159 | INFO     | __main__:imageflow_demo:240 - Processing frame 320 (10.60 fps)
# 2026-08-04 18:41:30.964 | INFO     | __main__:imageflow_demo:240 - Processing frame 340 (10.62 fps)
# 2026-08-04 18:41:35.052 | INFO     | __main__:imageflow_demo:240 - Processing frame 360 (10.63 fps)
# 2026-08-04 18:41:39.434 | INFO     | __main__:imageflow_demo:240 - Processing frame 380 (10.62 fps)
# 2026-08-04 18:41:43.322 | INFO     | __main__:imageflow_demo:240 - Processing frame 400 (10.63 fps)
# 2026-08-04 18:41:47.186 | INFO     | __main__:imageflow_demo:240 - Processing frame 420 (10.63 fps)
# 2026-08-04 18:41:51.862 | INFO     | __main__:imageflow_demo:240 - Processing frame 440 (10.62 fps)
# 2026-08-04 18:41:55.719 | INFO     | __main__:imageflow_demo:240 - Processing frame 460 (10.63 fps)
# 2026-08-04 18:41:59.611 | INFO     | __main__:imageflow_demo:240 - Processing frame 480 (10.65 fps)
# 2026-08-04 18:42:03.992 | INFO     | __main__:imageflow_demo:240 - Processing frame 500 (10.65 fps)
# 2026-08-04 18:42:08.296 | INFO     | __main__:imageflow_demo:240 - Processing frame 520 (10.65 fps)
# 2026-08-04 18:42:12.295 | INFO     | __main__:imageflow_demo:240 - Processing frame 540 (10.65 fps)
# 2026-08-04 18:42:16.653 | INFO     | __main__:imageflow_demo:240 - Processing frame 560 (10.64 fps)
# 2026-08-04 18:42:21.467 | INFO     | __main__:imageflow_demo:240 - Processing frame 580 (10.63 fps)
# 2026-08-04 18:42:25.537 | INFO     | __main__:imageflow_demo:240 - Processing frame 600 (10.63 fps)
# 2026-08-04 18:42:29.597 | INFO     | __main__:imageflow_demo:240 - Processing frame 620 (10.63 fps)
# 2026-08-04 18:42:34.271 | INFO     | __main__:imageflow_demo:240 - Processing frame 640 (10.63 fps)
# 2026-08-04 18:42:36.785 | INFO     | __main__:imageflow_demo:279 - save results to ./YOLOX_outputs/yolox_x_mix_det_hybrid_sort/False/track_vis/2026_08_04_18_40_20.txt
#  💾 [Telemetri] Düzeltilmiş Koordinatlar Drive'a kilitlendi: MOT17-10-FRCNN.txt
#  🎨 [Stage 3.5] Render Stüdyosu...
#  🎬 [Final Tracked (MOT17-10-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Final Tracked (MOT17-10-FRCNN)] Mühürleme Başarılı! (43.96 MB)
#
# ══════════════════════════════════════════════════════════════════════
# 🎯 İŞLENEN SEKANS (STAGE SWAP): MOT17-11-FRCNN
# ══════════════════════════════════════════════════════════════════════
#  🚀 [Stage 1 - STAB] LightStab Çalıştırılıyor (Ham Video Üzerinde)...
#  🎬 [Stage 1 Stab (MOT17-11-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 1 Stab (MOT17-11-FRCNN)] Mühürleme Başarılı! (55.93 MB)
#  🚀 [Stage 2 - DEBLUR] DeepRFT SOTA Başlatılıyor (Sarsıntısı Alınmış Video Üzerinde)...
#  🎬 [Stage 2 Deblur (MOT17-11-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 2 Deblur (MOT17-11-FRCNN)] Mühürleme Başarılı! (58.56 MB)
#  🚀 [Stage 3] Hybrid-SORT Takip Motoru...
# 2026-08-04 19:30:12.002 | INFO     | __main__:imageflow_demo:240 - Processing frame 0 (100000.00 fps)
# 2026-08-04 19:30:16.385 | INFO     | __main__:imageflow_demo:240 - Processing frame 20 (9.74 fps)
# 2026-08-04 19:30:20.404 | INFO     | __main__:imageflow_demo:240 - Processing frame 40 (10.54 fps)
# 2026-08-04 19:30:24.942 | INFO     | __main__:imageflow_demo:240 - Processing frame 60 (10.76 fps)
# 2026-08-04 19:30:28.834 | INFO     | __main__:imageflow_demo:240 - Processing frame 80 (11.00 fps)
# 2026-08-04 19:30:32.677 | INFO     | __main__:imageflow_demo:240 - Processing frame 100 (11.17 fps)
# 2026-08-04 19:30:37.260 | INFO     | __main__:imageflow_demo:240 - Processing frame 120 (11.22 fps)
# 2026-08-04 19:30:41.263 | INFO     | __main__:imageflow_demo:240 - Processing frame 140 (11.27 fps)
# 2026-08-04 19:30:45.082 | INFO     | __main__:imageflow_demo:240 - Processing frame 160 (11.35 fps)
# 2026-08-04 19:30:49.200 | INFO     | __main__:imageflow_demo:240 - Processing frame 180 (11.40 fps)
# 2026-08-04 19:30:53.612 | INFO     | __main__:imageflow_demo:240 - Processing frame 200 (11.41 fps)
# 2026-08-04 19:30:57.407 | INFO     | __main__:imageflow_demo:240 - Processing frame 220 (11.47 fps)
# 2026-08-04 19:31:01.287 | INFO     | __main__:imageflow_demo:240 - Processing frame 240 (11.50 fps)
# 2026-08-04 19:31:05.927 | INFO     | __main__:imageflow_demo:240 - Processing frame 260 (11.49 fps)
# 2026-08-04 19:31:09.805 | INFO     | __main__:imageflow_demo:240 - Processing frame 280 (11.51 fps)
# 2026-08-04 19:31:13.677 | INFO     | __main__:imageflow_demo:240 - Processing frame 300 (11.54 fps)
# 2026-08-04 19:31:17.940 | INFO     | __main__:imageflow_demo:240 - Processing frame 320 (11.55 fps)
# 2026-08-04 19:31:22.340 | INFO     | __main__:imageflow_demo:240 - Processing frame 340 (11.54 fps)
# 2026-08-04 19:31:26.213 | INFO     | __main__:imageflow_demo:240 - Processing frame 360 (11.55 fps)
# 2026-08-04 19:31:30.121 | INFO     | __main__:imageflow_demo:240 - Processing frame 380 (11.56 fps)
# 2026-08-04 19:31:34.797 | INFO     | __main__:imageflow_demo:240 - Processing frame 400 (11.56 fps)
# 2026-08-04 19:31:38.627 | INFO     | __main__:imageflow_demo:240 - Processing frame 420 (11.58 fps)
# 2026-08-04 19:31:42.464 | INFO     | __main__:imageflow_demo:240 - Processing frame 440 (11.59 fps)
# 2026-08-04 19:31:46.804 | INFO     | __main__:imageflow_demo:240 - Processing frame 460 (11.60 fps)
# 2026-08-04 19:31:50.980 | INFO     | __main__:imageflow_demo:240 - Processing frame 480 (11.60 fps)
# 2026-08-04 19:31:54.821 | INFO     | __main__:imageflow_demo:240 - Processing frame 500 (11.62 fps)
# 2026-08-04 19:31:58.792 | INFO     | __main__:imageflow_demo:240 - Processing frame 520 (11.63 fps)
# 2026-08-04 19:32:03.450 | INFO     | __main__:imageflow_demo:240 - Processing frame 540 (11.62 fps)
# 2026-08-04 19:32:07.324 | INFO     | __main__:imageflow_demo:240 - Processing frame 560 (11.62 fps)
# 2026-08-04 19:32:11.142 | INFO     | __main__:imageflow_demo:240 - Processing frame 580 (11.64 fps)
# 2026-08-04 19:32:15.605 | INFO     | __main__:imageflow_demo:240 - Processing frame 600 (11.64 fps)
# 2026-08-04 19:32:19.674 | INFO     | __main__:imageflow_demo:240 - Processing frame 620 (11.64 fps)
# 2026-08-04 19:32:23.489 | INFO     | __main__:imageflow_demo:240 - Processing frame 640 (11.65 fps)
# 2026-08-04 19:32:27.461 | INFO     | __main__:imageflow_demo:240 - Processing frame 660 (11.66 fps)
# 2026-08-04 19:32:32.069 | INFO     | __main__:imageflow_demo:240 - Processing frame 680 (11.66 fps)
# 2026-08-04 19:32:35.914 | INFO     | __main__:imageflow_demo:240 - Processing frame 700 (11.66 fps)
# 2026-08-04 19:32:39.728 | INFO     | __main__:imageflow_demo:240 - Processing frame 720 (11.67 fps)
# 2026-08-04 19:32:44.359 | INFO     | __main__:imageflow_demo:240 - Processing frame 740 (11.66 fps)
# 2026-08-04 19:32:48.403 | INFO     | __main__:imageflow_demo:240 - Processing frame 760 (11.66 fps)
# 2026-08-04 19:32:52.372 | INFO     | __main__:imageflow_demo:240 - Processing frame 780 (11.66 fps)
# 2026-08-04 19:32:56.589 | INFO     | __main__:imageflow_demo:240 - Processing frame 800 (11.66 fps)
# 2026-08-04 19:33:01.130 | INFO     | __main__:imageflow_demo:240 - Processing frame 820 (11.66 fps)
# 2026-08-04 19:33:05.140 | INFO     | __main__:imageflow_demo:240 - Processing frame 840 (11.65 fps)
# 2026-08-04 19:33:09.146 | INFO     | __main__:imageflow_demo:240 - Processing frame 860 (11.64 fps)
# 2026-08-04 19:33:14.037 | INFO     | __main__:imageflow_demo:240 - Processing frame 880 (11.63 fps)
# 2026-08-04 19:33:17.823 | INFO     | __main__:imageflow_demo:279 - save results to ./YOLOX_outputs/yolox_x_mix_det_hybrid_sort/False/track_vis/2026_08_04_19_30_11.txt
#  💾 [Telemetri] Düzeltilmiş Koordinatlar Drive'a kilitlendi: MOT17-11-FRCNN.txt
#  🎨 [Stage 3.5] Render Stüdyosu...
#  🎬 [Final Tracked (MOT17-11-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Final Tracked (MOT17-11-FRCNN)] Mühürleme Başarılı! (63.77 MB)
#
# ══════════════════════════════════════════════════════════════════════
# 🎯 İŞLENEN SEKANS (STAGE SWAP): MOT17-13-FRCNN
# ══════════════════════════════════════════════════════════════════════
#  🚀 [Stage 1 - STAB] LightStab Çalıştırılıyor (Ham Video Üzerinde)...
#  🎬 [Stage 1 Stab (MOT17-13-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 1 Stab (MOT17-13-FRCNN)] Mühürleme Başarılı! (43.29 MB)
#  🚀 [Stage 2 - DEBLUR] DeepRFT SOTA Başlatılıyor (Sarsıntısı Alınmış Video Üzerinde)...
#  🎬 [Stage 2 Deblur (MOT17-13-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Stage 2 Deblur (MOT17-13-FRCNN)] Mühürleme Başarılı! (46.65 MB)
#  🚀 [Stage 3] Hybrid-SORT Takip Motoru...
# 2026-08-04 20:14:29.627 | INFO     | __main__:imageflow_demo:240 - Processing frame 0 (100000.00 fps)
# 2026-08-04 20:14:34.656 | INFO     | __main__:imageflow_demo:240 - Processing frame 20 (8.68 fps)
# 2026-08-04 20:14:38.593 | INFO     | __main__:imageflow_demo:240 - Processing frame 40 (9.61 fps)
# 2026-08-04 20:14:42.588 | INFO     | __main__:imageflow_demo:240 - Processing frame 60 (9.90 fps)
# 2026-08-04 20:14:47.358 | INFO     | __main__:imageflow_demo:240 - Processing frame 80 (9.92 fps)
# 2026-08-04 20:14:51.265 | INFO     | __main__:imageflow_demo:240 - Processing frame 100 (10.05 fps)
# 2026-08-04 20:14:55.146 | INFO     | __main__:imageflow_demo:240 - Processing frame 120 (10.12 fps)
# 2026-08-04 20:14:59.606 | INFO     | __main__:imageflow_demo:240 - Processing frame 140 (10.11 fps)
# 2026-08-04 20:15:03.743 | INFO     | __main__:imageflow_demo:240 - Processing frame 160 (10.13 fps)
# 2026-08-04 20:15:07.621 | INFO     | __main__:imageflow_demo:240 - Processing frame 180 (10.17 fps)
# 2026-08-04 20:15:11.650 | INFO     | __main__:imageflow_demo:240 - Processing frame 200 (10.21 fps)
# 2026-08-04 20:15:16.105 | INFO     | __main__:imageflow_demo:240 - Processing frame 220 (10.22 fps)
# 2026-08-04 20:15:19.923 | INFO     | __main__:imageflow_demo:240 - Processing frame 240 (10.26 fps)
# 2026-08-04 20:15:23.711 | INFO     | __main__:imageflow_demo:240 - Processing frame 260 (10.31 fps)
# 2026-08-04 20:15:28.258 | INFO     | __main__:imageflow_demo:240 - Processing frame 280 (10.33 fps)
# 2026-08-04 20:15:32.123 | INFO     | __main__:imageflow_demo:240 - Processing frame 300 (10.36 fps)
# 2026-08-04 20:15:35.957 | INFO     | __main__:imageflow_demo:240 - Processing frame 320 (10.38 fps)
# 2026-08-04 20:15:40.086 | INFO     | __main__:imageflow_demo:240 - Processing frame 340 (10.39 fps)
# 2026-08-04 20:15:44.443 | INFO     | __main__:imageflow_demo:240 - Processing frame 360 (10.38 fps)
# 2026-08-04 20:15:48.259 | INFO     | __main__:imageflow_demo:240 - Processing frame 380 (10.40 fps)
# 2026-08-04 20:15:52.024 | INFO     | __main__:imageflow_demo:240 - Processing frame 400 (10.43 fps)
# 2026-08-04 20:15:56.591 | INFO     | __main__:imageflow_demo:240 - Processing frame 420 (10.42 fps)
# 2026-08-04 20:16:00.422 | INFO     | __main__:imageflow_demo:240 - Processing frame 440 (10.44 fps)
# 2026-08-04 20:16:04.268 | INFO     | __main__:imageflow_demo:240 - Processing frame 460 (10.44 fps)
# 2026-08-04 20:16:08.602 | INFO     | __main__:imageflow_demo:240 - Processing frame 480 (10.43 fps)
# 2026-08-04 20:16:12.733 | INFO     | __main__:imageflow_demo:240 - Processing frame 500 (10.46 fps)
# 2026-08-04 20:16:16.525 | INFO     | __main__:imageflow_demo:240 - Processing frame 520 (10.49 fps)
# 2026-08-04 20:16:20.327 | INFO     | __main__:imageflow_demo:240 - Processing frame 540 (10.51 fps)
# 2026-08-04 20:16:25.018 | INFO     | __main__:imageflow_demo:240 - Processing frame 560 (10.52 fps)
# 2026-08-04 20:16:28.882 | INFO     | __main__:imageflow_demo:240 - Processing frame 580 (10.53 fps)
# 2026-08-04 20:16:32.665 | INFO     | __main__:imageflow_demo:240 - Processing frame 600 (10.56 fps)
# 2026-08-04 20:16:36.917 | INFO     | __main__:imageflow_demo:240 - Processing frame 620 (10.58 fps)
# 2026-08-04 20:16:41.027 | INFO     | __main__:imageflow_demo:240 - Processing frame 640 (10.60 fps)
# 2026-08-04 20:16:44.838 | INFO     | __main__:imageflow_demo:240 - Processing frame 660 (10.62 fps)
# 2026-08-04 20:16:48.618 | INFO     | __main__:imageflow_demo:240 - Processing frame 680 (10.64 fps)
# 2026-08-04 20:16:53.147 | INFO     | __main__:imageflow_demo:240 - Processing frame 700 (10.65 fps)
# 2026-08-04 20:16:56.894 | INFO     | __main__:imageflow_demo:240 - Processing frame 720 (10.67 fps)
# 2026-08-04 20:17:00.679 | INFO     | __main__:imageflow_demo:240 - Processing frame 740 (10.69 fps)
# 2026-08-04 20:17:02.368 | INFO     | __main__:imageflow_demo:279 - save results to ./YOLOX_outputs/yolox_x_mix_det_hybrid_sort/False/track_vis/2026_08_04_20_14_29.txt
#  💾 [Telemetri] Düzeltilmiş Koordinatlar Drive'a kilitlendi: MOT17-13-FRCNN.txt
#  🎨 [Stage 3.5] Render Stüdyosu...
#  🎬 [Final Tracked (MOT17-13-FRCNN)] H.264 (YUV420P) formatında renk korumalı mühürleniyor...
#  ✅ [Final Tracked (MOT17-13-FRCNN)] Mühürleme Başarılı! (44.72 MB)
#
# 🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆
#  🎉 STAGE SWAP DENEYİ (STAB -> DEBLUR) MÜHÜRLENDİ! 🎉
# 🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆🏆

# %%
# ==============================================================================
# 📈 BATCH EVALUATION V7.1: TRACKEVAL + DİNAMİK GÖRSEL KALİTE (STAGE SWAP)
# ==============================================================================
import os
import sys
import subprocess
import shutil
import glob
import re
import cv2
import numpy as np

# scikit-image kütüphanesi yoksa kur
try:
    from skimage.metrics import peak_signal_noise_ratio as psnr
    from skimage.metrics import structural_similarity as ssim
except ImportError:
    subprocess.run([sys.executable, "-m", "pip", "install", "scikit-image", "-q"])
    from skimage.metrics import peak_signal_noise_ratio as psnr
    from skimage.metrics import structural_similarity as ssim

print("📊 [Ablation Metrics Engine] Drive-Merkezli Swap Telemetri Eşleştirici Başlatılıyor...\n")

trackeval_path = "/content/TrackEval"
if not os.path.exists(trackeval_path):
    print(" 📥 TrackEval klonlanıyor...")
    subprocess.run(["git", "clone", "https://github.com/JonathonLuiten/TrackEval.git", trackeval_path])

# NumPy Uyumluluk Yaması
for py_file in glob.glob(os.path.join(trackeval_path, "**/*.py"), recursive=True):
    try:
        with open(py_file, 'r', encoding='utf-8') as f: code = f.read()
        code = re.sub(r'\bnp\.float\b', 'float', code)
        code = re.sub(r'\bnp\.int\b', 'int', code)
        code = re.sub(r'\bnp\.bool\b', 'bool', code)
        code = re.sub(r'\bnp\.object\b', 'object', code)
        with open(py_file, 'w', encoding='utf-8') as f: f.write(code)
    except Exception: pass

sequences = [
    "MOT17-02-FRCNN", "MOT17-04-FRCNN", "MOT17-05-FRCNN",
    "MOT17-09-FRCNN", "MOT17-10-FRCNN", "MOT17-11-FRCNN", "MOT17-13-FRCNN"
]

tracker_name = "HybridSORT_Official"
data_dir = os.path.join(trackeval_path, "data/trackers/mot_challenge/MOT17-train", tracker_name, "data")
os.makedirs(data_dir, exist_ok=True)

# Ground Truth (GT) Bağlantısı
drive_gt_dir = "/content/drive/MyDrive/Spikedge_Staj/Tracking/MOT17_Dataset/train"
trackeval_gt_dir = os.path.join(trackeval_path, "data/gt/mot_challenge/MOT17-train")

if os.path.exists(drive_gt_dir) and not os.path.exists(trackeval_gt_dir):
    os.makedirs(os.path.dirname(trackeval_gt_dir), exist_ok=True)
    os.symlink(drive_gt_dir, trackeval_gt_dir)

DRIVE_TELEMETRY = "/content/drive/MyDrive/Spikedge_Staj/Tracking/telemetry_swap"
found_count = 0

for seq in sequences:
    src_txt = os.path.join(DRIVE_TELEMETRY, f"{seq}.txt")
    dest_txt = os.path.join(data_dir, f"{seq}.txt")

    if os.path.exists(src_txt):
        with open(src_txt, 'r') as f: lines = f.readlines()
        if not lines: continue

        delim = ',' if ',' in lines[0] else ' '
        min_frame = 999999
        for line in lines:
            if line.strip():
                try:
                    frm = int(float(line.strip().split(delim)[0]))
                    if frm < min_frame: min_frame = frm
                except: pass

        needs_shift = (min_frame == 0)
        seen_instances = set()
        clean_lines = []

        for line in lines:
            if not line.strip(): continue
            parts = line.strip().split(delim)
            if len(parts) >= 2:
                try:
                    frm = int(float(parts[0]))
                    if needs_shift: frm += 1
                    tid = int(float(parts[1]))

                    if (frm, tid) not in seen_instances:
                        seen_instances.add((frm, tid))
                        parts[0] = str(frm)
                        clean_lines.append(delim.join(parts))
                except:
                    clean_lines.append(line.strip())

        with open(dest_txt, 'w') as f:
            f.write("\n".join(clean_lines) + "\n")

        found_count += 1

if found_count == len(sequences):
    seqmap_dir = os.path.join(trackeval_path, "data/gt/mot_challenge/seqmaps")
    os.makedirs(seqmap_dir, exist_ok=True)
    with open(os.path.join(seqmap_dir, "MOT17-train.txt"), "w") as f:
        f.write("name\n")
        for seq in sequences: f.write(f"{seq}\n")

    print(" 🚀 TrackEval Kümülatif Motoru Çalıştırılıyor (Lütfen bekleyiniz)...\n")

    eval_cmd = [
        sys.executable, os.path.join(trackeval_path, "scripts/run_mot_challenge.py"),
        "--BENCHMARK", "MOT17", "--SPLIT_TO_EVAL", "train",
        "--TRACKERS_TO_EVAL", tracker_name,
        "--METRICS", "HOTA", "CLEAR", "Identity",
        "--USE_PARALLEL", "False", "--PRINT_RESULTS", "False"
    ]
    env = os.environ.copy()
    res = subprocess.run(eval_cmd, cwd=trackeval_path, capture_output=True, text=True, env=env)

    summary_file = os.path.join(trackeval_path, "data/trackers/mot_challenge/MOT17-train", tracker_name, "pedestrian_summary.txt")
    hota, mota, idf1, idsw, motp = "N/A", "N/A", "N/A", "N/A", "N/A"

    if os.path.exists(summary_file):
        with open(summary_file, 'r') as f:
            lines = f.readlines()
            if len(lines) >= 2:
                headers = lines[0].strip().split(' ')
                values = lines[1].strip().split(' ')
                val_dict = dict(zip(headers, values))

                hota = val_dict.get('HOTA', 'N/A')
                mota = val_dict.get('MOTA', 'N/A')
                idf1 = val_dict.get('IDF1', 'N/A')
                idsw = val_dict.get('IDSW', 'N/A')
                motp = val_dict.get('MOTP', 'N/A')

    # ==============================================================================
    # 🌟 DİNAMİK GÖRSEL KALİTE VE STABİLİZASYON METRİKLERİ (Örneklem: MOT17-04)
    # ==============================================================================
    print(" 🔍 Dinamik Görüntü Kalite ve Stabilizasyon (ITF) Analizi Başlatılıyor...")
    print(" ⚠️ Colab RAM optimizasyonu için analiz MOT17-04 sekansının ilk 100 karesi ile sınırlanmıştır.\n")

    raw_video_path = "/content/drive/MyDrive/Spikedge_Staj/Tracking/input_videos_train/MOT17-04-FRCNN_raw_input.mp4"
    # Stage Swap deneyinde Final görsel çıktı Stage 2'dir (Deblurred)
    final_video_path = "/content/drive/MyDrive/Spikedge_Staj/Tracking/intermediate_swap/stage2_deblurred_MOT17-04-FRCNN.mp4"

    psnr_list, ssim_list, itf_list = [], [], []

    if os.path.exists(raw_video_path) and os.path.exists(final_video_path):
        cap_raw = cv2.VideoCapture(raw_video_path)
        cap_fin = cv2.VideoCapture(final_video_path)

        frame_limit = 100
        count = 0
        prev_fin_frame = None

        while count < frame_limit:
            ret_r, f_raw = cap_raw.read()
            ret_f, f_fin = cap_fin.read()

            if not ret_r or not ret_f: break

            # Görüntüleri analize uygun formata (Grayscale) çevir
            f_raw_g = cv2.cvtColor(f_raw, cv2.COLOR_BGR2GRAY)
            f_fin_g = cv2.cvtColor(f_fin, cv2.COLOR_BGR2GRAY)

            # 1. PSNR ve SSIM (Ham Görüntüye Müdahale Oranı)
            psnr_list.append(psnr(f_raw_g, f_fin_g))
            ssim_list.append(ssim(f_raw_g, f_fin_g))

            # 2. ITF (Stabilizasyon Pürüzsüzlüğü - Ardışık Kare Kıyaslaması)
            if prev_fin_frame is not None:
                itf_list.append(psnr(prev_fin_frame, f_fin_g))

            prev_fin_frame = f_fin_g
            count += 1

        cap_raw.release()
        cap_fin.release()

        dyn_psnr = f"{np.mean(psnr_list):.2f}" if psnr_list else "N/A"
        dyn_ssim = f"{np.mean(ssim_list):.4f}" if ssim_list else "N/A"
        dyn_itf = f"{np.mean(itf_list):.2f}" if itf_list else "N/A"
    else:
        dyn_psnr, dyn_ssim, dyn_itf = "N/A", "N/A", "N/A"

    print("=====================================================================================")
    print(" 🧪 ABLASYON DENEYİ SONUÇLARI (STAGE SWAP: Önce Stabilizasyon, Sonra Netleştirme)")
    print("=====================================================================================")
    print(" 🔬 [Dinamik Görüntü Kalitesi - MOT17-04 Örneklemi]")
    print(f"    • Ortalama PSNR (Müdahale Oranı)           : {dyn_psnr} dB")
    print(f"    • Ortalama SSIM (Yapısal Benzerlik İndeksi): {dyn_ssim}")
    print(f"    • Dinamik ITF (Kareler Arası Stabilizasyon): {dyn_itf} dB")
    print("-------------------------------------------------------------------------------------")
    print(" 📊 KÜMÜLATİF (COMBINED) AKADEMİK METRİKLER:")
    print(f"    ➤ HOTA (Genel Başarı)     : {hota} %")
    print(f"    ➤ MOTA (Takip Doğruluğu)  : {mota} %")
    print(f"    ➤ IDF1 (Kimlik Koruma)    : {idf1} %")
    print(f"    ➤ MOTP (Kutu Hassasiyeti) : {motp} %")
    print(f"    ➤ IDSW (Kimlik Değişimi)  : {idsw}")
    print("=====================================================================================")
    print(" 💡 Mühendislik Notu: Kalite metrikleri (PSNR/SSIM) orijinal net bir referans olmadığı ")
    print("    için ham videoya kıyasla hesaplanmıştır. ITF ise stabilizasyonu ölçmektedir.")
    print("=====================================================================================")
else:
    print(f"\n 🛑 [DURDURULDU] Yalnızca {found_count}/{len(sequences)} telemetri dosyası bulundu. Lütfen 'telemetry_swap' klasörünü kontrol edin.")
# Out:
# 📊 [Ablation Metrics Engine] Drive-Merkezli Swap Telemetri Eşleştirici Başlatılıyor...
#
#  🚀 TrackEval Kümülatif Motoru Çalıştırılıyor (Lütfen bekleyiniz)...
#
#  🔍 Dinamik Görüntü Kalite ve Stabilizasyon (ITF) Analizi Başlatılıyor...
#  ⚠️ Colab RAM optimizasyonu için analiz MOT17-04 sekansının ilk 100 karesi ile sınırlanmıştır.
#
# =====================================================================================
#  🧪 ABLASYON DENEYİ SONUÇLARI (STAGE SWAP: Önce Stabilizasyon, Sonra Netleştirme)
# =====================================================================================
#  🔬 [Dinamik Görüntü Kalitesi - MOT17-04 Örneklemi]
#     • Ortalama PSNR (Müdahale Oranı)           : 33.33 dB
#     • Ortalama SSIM (Yapısal Benzerlik İndeksi): 0.9659
#     • Dinamik ITF (Kareler Arası Stabilizasyon): 36.00 dB
# -------------------------------------------------------------------------------------
#  📊 KÜMÜLATİF (COMBINED) AKADEMİK METRİKLER:
#     ➤ HOTA (Genel Başarı)     : 72.391 %
#     ➤ MOTA (Takip Doğruluğu)  : 83.631 %
#     ➤ IDF1 (Kimlik Koruma)    : 81.409 %
#     ➤ MOTP (Kutu Hassasiyeti) : 85.758 %
#     ➤ IDSW (Kimlik Değişimi)  : 546
# =====================================================================================
#  💡 Mühendislik Notu: Kalite metrikleri (PSNR/SSIM) orijinal net bir referans olmadığı
#     için ham videoya kıyasla hesaplanmıştır. ITF ise stabilizasyonu ölçmektedir.
# =====================================================================================

# %%
# ==============================================================================
# 🎬 PIPELINE VİZYON MOTORU: 2x2 GRID (YAN YANA GÖRSELLEŞTİRME)
# ==============================================================================
import os
import subprocess
from IPython.display import HTML
from base64 import b64encode

print("🎬 [Vision Engine] 2x2 Grid Render Motoru Başlatılıyor...\n")

# ⚠️ BURAYI KENDİ DRIVE YOLLARINA GÖRE GÜNCELLE (Örnek olarak MOT17-04 seçilmiştir)
# Dosyaların tam nerede olduğunu Drive'dan kopyala/yapıştır.
vid_input = "/content/drive/MyDrive/Spikedge_Staj/Tracking/input_videos_test/MOT17-08-FRCNN_raw_input.mp4"
vid_stage1 = "/content/drive/MyDrive/Spikedge_Staj/Tracking/intermediate_test/stage1_deblurred_MOT17-08-FRCNN.mp4"
vid_stage2 = "/content/drive/MyDrive/Spikedge_Staj/Tracking/intermediate_test/stage2_stabilized_MOT17-08-FRCNN.mp4"
vid_final = "/content/drive/MyDrive/Spikedge_Staj/Tracking/output_tracks_test/final_tracked_MOT17-08-FRCNN.mp4"

output_grid = "/content/drive/MyDrive/Spikedge_Staj/Tracking/Dashboard_MOT17-04_Grid.mp4"

# Dosya kontrolü
for v, name in zip([vid_input, vid_stage1, vid_stage2, vid_final], ["Input", "Stage1", "Stage2", "Final"]):
    if not os.path.exists(v):
        print(f" ❌ HATA: {name} videosu bulunamadı! Yol: {v}")
    else:
        print(f" ✔️ {name} doğrulandı.")

print("\n ⚙️ FFmpeg Complex Filter Ağacı Kuruluyor (Bu işlem 3-5 dakika sürebilir)...")

# FFmpeg Complex Filter Komutu
# Her videoyu 960x540'a küçültüyor, üzerlerine isimlerini yazıyor ve 2x2 birleştiriyor.
ffmpeg_cmd = [
    "ffmpeg", "-y",
    "-i", vid_input,
    "-i", vid_stage1,
    "-i", vid_stage2,
    "-i", vid_final,
    "-filter_complex",
    """
    [0:v]scale=960:540,drawtext=text='1. RAW INPUT':fontcolor=white:fontsize=36:box=1:boxcolor=black@0.6:x=20:y=20[v0];
    [1:v]scale=960:540,drawtext=text='2. STAGE 1 (DEBLURRING)':fontcolor=white:fontsize=36:box=1:boxcolor=black@0.6:x=20:y=20[v1];
    [2:v]scale=960:540,drawtext=text='3. STAGE 2 (STABILIZATION)':fontcolor=white:fontsize=36:box=1:boxcolor=black@0.6:x=20:y=20[v2];
    [3:v]scale=960:540,drawtext=text='4. FINAL OUTPUT (HybridSORT)':fontcolor=white:fontsize=36:box=1:boxcolor=black@0.6:x=20:y=20[v3];
    [v0][v1]hstack=inputs=2[top];
    [v2][v3]hstack=inputs=2[bottom];
    [top][bottom]vstack=inputs=2[out]
    """,
    "-map", "[out]",
    "-c:v", "libx264", "-crf", "23", "-preset", "fast",
    output_grid
]

# Render İşlemi
try:
    subprocess.run(ffmpeg_cmd, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(" ✅ Render Başarılı! 2x2 Grid Video Drive'a Kaydedildi.")
except subprocess.CalledProcessError as e:
    print(" ❌ Render Hatası! Hata detayı:\n", e.stderr.decode('utf-8'))

# ==============================================================================
# 📺 COLAB İÇİNDE OYNATMA (HTML5)
# ==============================================================================
print(" 📺 Video Colab Ekranına Yansıtılıyor...")

if os.path.exists(output_grid):
    mp4 = open(output_grid,'rb').read()
    data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

    display(HTML(f"""
    <video width="100%" controls>
          <source src="{data_url}" type="video/mp4">
    </video>
    """))
else:
    print("⚠️ Video dosyası Colab'e aktarılamadı, lütfen Drive'dan kontrol edin.")
